# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
movies = pd.read_csv('titles.csv')
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244914 entries, 0 to 244913
# Data columns (total 2 columns):
# title    244914 non-null object
# year     244914 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 3.7+ MB

# %%
movies.head()
# Out:
#                         title  year
# 0        The Fall of an Actor  2009
# 1               Angely smerti  1993
# 2           The Night Message  1924
# 3               Riley the Cop  1928
# 4  Charros, gauchos y manolas  1930

# %%
cast = pd.read_csv('cast.csv')
cast.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3786176 entries, 0 to 3786175
# Data columns (total 6 columns):
# title        object
# year         int64
# name         object
# type         object
# character    object
# n            float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 173.3+ MB

# %%
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
release_dates = pd.read_csv('release_dates.csv', parse_dates=['date'], infer_datetime_format=True)
release_dates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479488 entries, 0 to 479487
# Data columns (total 4 columns):
# title      479488 non-null object
# year       479488 non-null int64
# country    479488 non-null object
# date       479488 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 14.6+ MB

# %%
release_dates.head()
# Out:
#                     title  year      country       date
# 0   #73, Shaanthi Nivaasa  2007        India 2007-06-15
# 1                   #BKKY  2016     Cambodia 2017-10-12
# 2                 #Beings  2015      Romania 2015-01-29
# 3               #Captured  2017          USA 2017-09-05
# 4  #Ewankosau saranghaeyo  2015  Philippines 2015-01-21

# %%
len(movies)
# Out:
# 244914

# %%
#List all Batman movies ever made
batman = movies[movies.title.str.contains('Batman')]
batman
# Out:
#                                               title  year
# 4695                               Batman and Robin  1949
# 21344                        Batman: Master of Fear  2017
# 35434                                        Batman  1943
# 45432                                        Batman  1989
# 62599                  Batman: Mask of the Phantasm  1993
# 70244            Batman v Superman: Dawn of Justice  2016
# 72081                                  Batman Ninja  2018
# 83555                     Batman: The Final Victory  2010
# 94920                                Batman Returns  1992
# 98173                         The LEGO Batman Movie  2017
# 109848                 Batman Beyond: Rising Knight  2014
# 114229                             Batman: Crusader  2014
# 123973                        Batman Fights Dracula  1967
# 124120                  Batman the Rise of Red Hood  2018
# 131927                                 James Batman  1966
# ...

# %%
batman = movies[movies.title.str.contains('Batman')].sort_values(by=['year']).iloc[:15]
batman
# Out:
#                                title  year
# 35434                         Batman  1943
# 4695                Batman and Robin  1949
# 216879                Batman Dracula  1964
# 136836         Alyas Batman at Robin  1965
# 184214             Batman: The Movie  1966
# 131927                  James Batman  1966
# 123973         Batman Fights Dracula  1967
# 171247         Fight! Batman, Fight!  1973
# 45432                         Batman  1989
# 142273         Alyas Batman en Robin  1991
# 94920                 Batman Returns  1992
# 62599   Batman: Mask of the Phantasm  1993
# 184536                Batman Forever  1995
# 175164                Batman & Robin  1997
# 180123                 Batman Begins  2005

# %%
#List all the 'Harry Potter' movies from the most recent to the earliest
harry = movies[movies.title.str.contains('Harry Potter')].sort_values(by='year',ascending=False)
harry
# Out:
#                                                title  year
# 6464    Harry Potter and the Deathly Hallows: Part 2  2011
# 140685  Harry Potter and the Deathly Hallows: Part 1  2010
# 27479         Harry Potter and the Half-Blood Prince  2009
# 141455     Harry Potter and the Order of the Phoenix  2007
# 225101           Harry Potter and the Goblet of Fire  2005
# 99745       Harry Potter and the Prisoner of Azkaban  2004
# 89501        Harry Potter and the Chamber of Secrets  2002
# 62816          Harry Potter and the Sorcerer's Stone  2001

# %%
len(movies[movies.year == 2017])
# Out:
# 11474

# %%
#Section I - Q2 : How many movies were made in the year 2015?
len(movies[movies.year == 2015])
# Out:
# 8702

# %%
#Section I - Q3 : How many movies were made from 2000 till 2018?
len(movies[(movies.year > 1999) & (movies.year < 2019)])
# Out:
# 114070

# %%
#Section I - Q4: How many movies are titled "Hamlet"?
len(movies[movies.title.str.contains('Hamlet')])
# Out:
# 57

# %%
#Section I - Q5: List all movies titled "Hamlet"
#The movies should only have been released on or after the year 2000
#Display the movies based on the year they were released (earliest to most recent)
hamlet = movies[movies.title.str.contains('Hamlet')][ movies.year > 1999].sort_values(by='year',ascending=True)
hamlet
# Out:
# C:\Users\Rose-Marie\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
#                                           title  year
# 137339                                   Hamlet  2000
# 206173                   Hamlet in the Hamptons  2002
# 11392                                  Hamlet_X  2003
# 106452                                 Hamlet X  2004
# 148668          Dogg's Hamlet, Cahoot's Macbeth  2005
# 145837                              Hamlet (II)  2005
# 40261   The Tragedy of Hamlet Prince of Denmark  2007
# 57691                              Hamlet (III)  2007
# 139226                              Hamlet (II)  2007
# 86254                                  Hamlet 2  2008
# 169477                Hamlet the Vampire Slayer  2008
# 29934                            Kitchen Hamlet  2009
# 203525                                   Hamlet  2009
# ...

# %%
#Section I - Q6: How many roles in the movie "Inception" are of the supporting cast (extra credits)
#supporting cast are NOT ranked by an "n" value (NaN)
inception_sup = cast[(cast.title == 'Inception') & cast.n.isnull()]
print ("Number of supporting cast roles in Inception: ", len(inception_sup))
inception_sup
# Out:
# Number of supporting cast roles in Inception:  27
#              title  year                     name     type  \
# 98153    Inception  2010     Michael (III) August    actor
# 197877   Inception  2010                 Ken Bhan    actor
# 374661   Inception  2010            John Ceallach    actor
# 497161   Inception  2010             Garvin Cross    actor
# 684098   Inception  2010            Seve Esposito    actor
# 690634   Inception  2010      Marcus (II) Everett    actor
# 707642   Inception  2010  Zachary Christopher Fay    actor
# 836295   Inception  2010        Daniel Girondeaud    actor
# 1006636  Inception  2010          Andrew Hoagland    actor
# 1095095  Inception  2010          Charles Jarrell    actor
# 1108755  Inception  2010            Seong-hwan Jo    actor
# 1120184  Inception  2010          Alonzo F. Jones    actor
# 1189066  Inception  2010               Mobin Khan    actor
# 1248176  Inception  2010            Shunsaku Kud?    actor
# ...

# %%
#Section I - Q7: How many roles in the movie "Inception" are of the main cast
#main cast always have an 'n' value
inception_main = cast[(cast.title == 'Inception') & cast.n.notnull()]
print ("Number of main cast roles in Inception: ", len(inception_main))
inception_main
# Out:
# Number of main cast roles in Inception:  51
#              title  year                  name     type  \
# 149008   Inception  2010          Peter Basham    actor
# 183937   Inception  2010          Tom Berenger    actor
# 260128   Inception  2010        Virgile Bramly    actor
# 326745   Inception  2010         Michael Caine    actor
# 333415   Inception  2010          Earl Cameron    actor
# 433867   Inception  2010         Nicolas Clerc    actor
# 444385   Inception  2010        Adam (IV) Cole    actor
# 517227   Inception  2010    Jean-Michel Dagory    actor
# 590576   Inception  2010     Leonardo DiCaprio    actor
# 709436   Inception  2010             Russ Fega    actor
# 737322   Inception  2010      Mark Fleischmann    actor
# 807795   Inception  2010        Michael Gaston    actor
# 812135   Inception  2010       Johnathan Geare    actor
# 832083   Inception  2010         Carl Gilliard    actor
# 833376   Inception  2010           Jack Gilroy    actor
# ...

# %%
#Section I - Q8: Show the top ten cast (actors\actresses) in the movie "Inception"
#Main cast always have an 'n' value
top15 = inception_main.sort_values(by='n',ascending=True)[:10]
top15
# Out:
#              title  year                  name     type        character     n
# 590576   Inception  2010     Leonardo DiCaprio    actor             Cobb   1.0
# 859993   Inception  2010  Joseph Gordon-Levitt    actor           Arthur   2.0
# 3387147  Inception  2010            Ellen Page  actress          Ariadne   3.0
# 940923   Inception  2010             Tom Hardy    actor            Eames   4.0
# 2406531  Inception  2010          Ken Watanabe    actor            Saito   5.0
# 1876301  Inception  2010            Dileep Rao    actor            Yusuf   6.0
# 1615709  Inception  2010        Cillian Murphy    actor   Robert Fischer   7.0
# 183937   Inception  2010          Tom Berenger    actor         Browning   8.0
# 2765969  Inception  2010      Marion Cotillard  actress              Mal   9.0
# 1826027  Inception  2010    Pete Postlethwaite    actor  Maurice Fischer  10.0

# %%
#Section I - Q9:
#(A) List all movies where there was a character 'Albus Dumbledore'
dumbledore = cast[cast.character.str.contains('Albus Dumbledore')]
dumbledore['title']
# Out:
# 704984                                       Epic Movie
# 792419     Harry Potter and the Deathly Hallows: Part 1
# 792420     Harry Potter and the Deathly Hallows: Part 2
# 792421              Harry Potter and the Goblet of Fire
# 792422           Harry Potter and the Half-Blood Prince
# 792423        Harry Potter and the Order of the Phoenix
# 792424         Harry Potter and the Prisoner of Azkaban
# 947789          Harry Potter and the Chamber of Secrets
# 947790            Harry Potter and the Sorcerer's Stone
# 1685537                           Ultimate Hero Project
# 1893421    Harry Potter and the Deathly Hallows: Part 1
# 2248085                                          Potter
# Name: title, dtype: object

# %%
#(B) Now modify the above to show only the actors who played the character 'Albus Dumbledore'
#For Part (B) remember the same actor might play the same role in multiple movies
dumbledore['name'].unique()
# Out:
# array(['Dane Farwell', 'Michael Gambon', 'Richard Harris',
#        "George (X) O'Connor", 'Toby Regbo', 'Timothy Tedmanson'],
#       dtype=object)

# %%
#Section I - Q10:
#(A) How many roles has 'Keanu Reeves' played throughout his career?
mrwick = cast[cast.name == 'Keanu Reeves'] 
print('No of roles Keanu Reeves has played: ', len(mrwick))

#How many UNIQUE roles has 'Keanu Reeves' played throughout his career?
mrwick2 = mrwick.character.unique()
print('No of unique roles Keanu Reeves has played: ', len(mrwick2))

#(B) List the leading roles that 'Keanu Reeves' played on or after 1999 in order by year.
john = cast[(cast.name == 'Keanu Reeves') & (cast.year > 1998)].sort_values(by='year',ascending=True)
john['character']
# Out:
# No of roles Keanu Reeves has played:  62
# No of unique roles Keanu Reeves has played:  56
# 1892370                 Himself
# 1892369                 Dogstar
# 1892390                     Neo
# 1892387        Donnie Barksdale
# 1892398                 Griffin
# 1892397             Shane Falco
# 1892383             Nelson Moss
# 1892358           Conor O'Neill
# 1892391                     Neo
# 1892379           Julian Mercer
# 1892392                     Neo
# 1892351                 Dogstar
# 1892348        John Constantine
# 1892400             Perry Lyman
# 1892388              Alex Wyler
# 1892343              Bob Arctor
# 1892382    Detective Tom Ludlow
# 1892385                  Klaatu
# 1892396            Chris Nadeau
# 1892359             Henry Torne
# 1892357                    John
# 1892342                     Kai
# 1892368             Donaka Mark
# 1892361               John Wick
# 1892366                    Evan
# 1892365                   Keanu
# ...

# %%
#Section I - Q11:
#(A) List the total number of actor and actress roles available from 1950 - 1960
act5060 = cast[(cast.year > 1949) & (cast.year < 1961)]
print ('The total number of actor & actress roles from 1950 - 1960 are',len(act5060))

#(B) List the total number of actor and actress roles available from 2007 - 2017
act0717 = cast[(cast.year > 2006) & (cast.year < 2018)]
print ('The total number of actor & actress roles from 2007 - 2017 are',len(act0717))
# Out:
# The total number of actor & actress roles from 1950 - 1960 are 234635
# The total number of actor & actress roles from 2007 - 2017 are 1452413

# %%
#Section I - Q12:
#(A) List the total number of leading roles available from 2000 to present 
#**What is the difference between leading and non-leading roles anyway??** Assumed to be n > 10 for non-leading
cast_lead = cast[(cast.year >1999) & (cast.n < 11)]
print ("Number of main cast roles from 2000 to present: ", len(cast_lead))

#(B) List the total number of non-leading roles available from 2000 - present (exclude support cast)
cast_nonlead = cast[(cast.year >1999) & (cast.n > 10)]
print ("Number of non-leading roles from 2000 to present: ", len(cast_nonlead))

#(C) List the total number of support\extra-credit roles available from 2000 - present
sup_cast = cast[(cast.year > 1999) & cast.n.isnull()]
print ("Number of supporting cast roles from 2000 to present: ", len(sup_cast))
# Out:
# Number of main cast roles from 2000 to present:  461385
# Number of non-leading roles from 2000 to present:  600893
# Number of supporting cast roles from 2000 to present:  887484

# %%
top_ten = movies.title.value_counts()[:10]
top_ten
# Out:
# Hamlet                  20
# Carmen                  17
# Macbeth                 16
# Maya                    12
# Temptation              12
# The Outsider            12
# Honeymoon               11
# Othello                 11
# The Three Musketeers    11
# Freedom                 11
# Name: title, dtype: int64

# %%
top_ten.plot(kind='barh')

# %%
#Section II - Q1: Which years in the 2000s saw the most movies released? (Show top 3)
movies2000 = movies[movies.year > 1999]['year'].value_counts()[:3]
movies2000
# Out:
# 2017    11474
# 2016     9440
# 2015     8702
# Name: year, dtype: int64

# %%
movies2020 = movies[movies.year > 2019]['year'].value_counts() #these are upcoming movies I guess...but 2115?? Okay...
movies2020
# Out:
# 2020    220
# 2021     34
# 2022     18
# 2024      6
# 2023      5
# 2026      1
# 2025      1
# 2115      1
# Name: year, dtype: int64

# %%
#Section II - Q2: # Plot the total number of films released per-decade (1890, 1900, 1910,....)
#Hint: Dividing the year and multiplying with a number might give you the decade the year falls into!

film_count = ((movies.year // 10) * 10).value_counts().sort_index()
film_count
# Out:
# 1890        3
# 1900       39
# 1910     6799
# 1920     9034
# 1930    10388
# 1940     8718
# 1950    12934
# 1960    17976
# 1970    19526
# 1980    21034
# 1990    22992
# 2000    39452
# 2010    75733
# 2020      285
# 2110        1
# Name: year, dtype: int64

# %%
film_count.plot(kind='bar').set_xlabel("Decade")
# Out:
# Text(0.5, 0, 'Decade')

# %%
#Section II - Q3:
#(A) What are the top 10 most common character names in movie history?
char_count = (cast.character).value_counts()[:10]
char_count
# Out:
# Himself        20746
# Dancer         12477
# Extra          11948
# Reporter        8434
# Student         7773
# Doctor          7669
# Party Guest     7245
# Policeman       7029
# Nurse           6999
# Bartender       6802
# Name: character, dtype: int64

# %%
#(B) Who are the top 10 people most often credited as "Herself" in movie history?
herself = cast[cast.character == 'Herself']['name'].value_counts()[:10]
herself
# Out:
# Queen Elizabeth II           12
# Mar?a Luisa (V) Mart?n        9
# Joyce Brothers                9
# Luisa Horga                   9
# Hillary Clinton               8
# Margaret Thatcher             8
# Marilyn Monroe                6
# Mar?a Isabel (III) Mart?n     6
# Joan Rivers                   6
# Rekha                         6
# Name: name, dtype: int64

# %%
#(C) Who are the top 10 people most often credited as "Himself" in movie history?
himself = cast[cast.character == 'Himself']['name'].value_counts()[:10]
himself
# Out:
# Adolf Hitler          99
# Richard Nixon         44
# Ronald Reagan         41
# John F. Kennedy       37
# George W. Bush        25
# Winston Churchill     24
# Martin Luther King    23
# Ron Jeremy            22
# Bill Clinton          22
# Benito Mussolini      21
# Name: name, dtype: int64

# %%
#Section II - Q4:
#(A) What are the top 10 most frequent roles that start with the word "Zombie"?
zombies = cast[cast.character.str.startswith('Zombie')]['character'].value_counts()[:10]
zombies
# Out:
# Zombie                         6264
# Zombie Horde                    206
# Zombie - Protestor - Victim      78
# Zombie Extra                     70
# Zombie Dancer                    43
# Zombie #1                        36
# Zombie Girl                      36
# Zombie #2                        31
# Zombie Vampire                   25
# Zombie Victim                    22
# Name: character, dtype: int64

# %%
#(B) What are the top 10 most frequent roles that start with the word "Police"?
police = cast[cast.character.str.startswith('Police')]['character'].value_counts()[:10]
police
# Out:
# Policeman              7029
# Police Officer         4808
# Police Inspector        742
# Police Sergeant         674
# Police officer          539
# Police                  456
# Policewoman             415
# Police Chief            410
# Police Captain          387
# Police Commissioner     337
# Name: character, dtype: int64

# %%
#Section II - Q5: Plot how many roles 'Keanu Reeves' has played in each year of his career.
wick = cast[cast.name == 'Keanu Reeves']['year'].value_counts().sort_index()
wick.plot(kind='bar')

# %%
#Section II - Q6: Plot the cast positions (n-values) of Keanu Reeve's roles through his career over the years.
wick = cast[cast.name == 'Keanu Reeves'].sort_values(by='year', ascending = True)
wick.plot(x = 'year', y= 'n', kind='bar', figsize = (15,6))
##CHECK THIS CODE - NOT SURE THIS IS WHAT IS REQUIRED

# %%
#Section II - Q7: Plot the number of "Hamlet" films made by each decade

# %%
#Section II - Q8:
#(A) How many leading roles were available to both actors and actresses, in the 1960s (1960-1969)?

#(B) How many leading roles were available to both actors and actresses, in the 2000s (2000-2009)?

#Hint: A specific value of n might indicate a leading role

# %%
#Section II - Q9: List, in order by year, each of the films in which Frank Oz has played more than 1 role.

# %%
#Section II - Q10: List each of the characters that Frank Oz has portrayed at least twice
